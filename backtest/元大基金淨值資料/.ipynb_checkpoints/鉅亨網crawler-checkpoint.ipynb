# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import numpy as np
import requests
import time
from bs4 import BeautifulSoup
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web
import re

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By

# Find all links to fund info 

# driver = webdriver.Chrome('/mnt/c/Users/bryan/OneDrive/Desktop/chromedriver/chromedriver.exe')
driver = webdriver.Chrome()
# driver.get('https://fund.cnyes.com/nav.aspx')

# 所有元大基金
# driver.get('http://fund.cdn.cnyes.com/nav.aspx?n=1&fundgroup=-%E5%9F%BA%E9%87%91%E9%A1%9E%E5%9E%8B-&CategoryLocal=-%E5%9F%BA%E9%87%91%E7%B5%84%E5%88%A5-&AllRegion=-%E6%8A%95%E8%B3%87%E5%8D%80%E5%9F%9F-&FundCompanyNameLocal=%E5%85%83%E5%A4%A7%E6%8A%95%E4%BF%A1&orderby=&fund=fundall&ddlindex=0,0,0,29')


# 所有野村基金
driver.get('http://fund.cdn.cnyes.com/nav.aspx?n=1&fundgroup=-%e5%9f%ba%e9%87%91%e9%a1%9e%e5%9e%8b-&CategoryLocal=-%e5%9f%ba%e9%87%91%e7%b5%84%e5%88%a5-&AllRegion=-%e6%8a%95%e8%b3%87%e5%8d%80%e5%9f%9f-&FundCompanyNameLocal=%e9%87%8e%e6%9d%91%e6%8a%95%e4%bf%a1&orderby=&fund=fundall&ddlindex=0,0,0,42')


time.sleep(5)

links = []

for i in range(10):
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    for item in soup.find_all('a'):
        link = item.get('href')
        if 'detail' in str(link) and link not in links:
            links.append(link)
    try:
        next_page = driver.find_element_by_id('example_next')
        next_page.click()
    except:
        break
        
funds = [x.split('/')[2] for x in links]

# %%
len(funds)
# Out:
# 176

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By

all_funds = []
# driver = webdriver.Chrome('/mnt/c/Users/bryan/OneDrive/Desktop/chromedriver/chromedriver.exe')
driver = webdriver.Chrome()

for i in range(len(funds)):
    try:
        name = funds[i]
        print(i + 1, name)
        link = 'https://fund.cnyes.com' + links[i]
        driver.get(link)
        time.sleep(5)

        content = []
        current = '1'
        while True:
            page_source = driver.page_source
            soup = BeautifulSoup(page_source, "html.parser")
            dates = []
            for info in soup.find_all('td', {'class':'_1JRsZ'}):
                dates.append(info.text)
                current = info.text


            nav = []
            for info in soup.find_all('td', {'class':False})[-30:]:
                if info.text != '0.00%' and info.text != '0.0000' and len(info.text)>0 and info.text[-1] != '%':
        #             print(info.text)
                    nav.append(info.text)

            content.append(pd.DataFrame({'Date':dates, name:nav}))

            try:
                next_page = driver.find_element_by_xpath("//a[contains(text(),'下一頁')]")
                next_page.click()
            except:
                break

            if '2016/01/04' in dates:
                break

        final = pd.concat(content)
        final.drop_duplicates(inplace = True)
        final.sort_values(['Date'], inplace = True)
        final.set_index(['Date'], inplace = True)
        all_funds.append(final)
        save = pd.concat(all_funds, axis = 1, sort = True)
        save.to_csv('野村基金淨值.csv')
        print(i + 1, name, 'complete')
    except:
        continue
    
    
save
# Out:
# 1 野村ｅ科技基金
# 1 野村ｅ科技基金 complete
# 2 野村高科技基金
# 2 野村高科技基金 complete
# 3 野村中小基金-累積類型
# 3 野村中小基金-累積類型 complete
# 4 野村優質基金-累積類型新臺幣計價
# 4 野村優質基金-累積類型新臺幣計價 complete
# 5 野村優質基金-S類型新臺幣累積
# 5 野村優質基金-S類型新臺幣累積 complete
# 6 野村台灣運籌基金
# 6 野村台灣運籌基金 complete
# 7 野村鴻運基金
# 7 野村鴻運基金 complete
# 8 野村積極成長基金
# 8 野村積極成長基金 complete
# 9 野村成長基金
# 9 野村成長基金 complete
# 10 野村鴻利基金
# 10 野村鴻利基金 complete
# 11 野村平衡基金
# 11 野村平衡基金 complete
# 12 野村巴西基金
# 12 野村巴西基金 complete
# 13 野村台灣高股息基金
# 13 野村台灣高股息基金 complete
# 14 野村新興傘型基金之大俄羅斯基金
# 14 野村新興傘型基金之大俄羅斯基金 complete
# 15 野村環球基金-人民幣計價
# 15 野村環球基金-人民幣計價 complete
# 16 野村動態配置多重資產基金-累積類型南非幣計價
# 16 野村動態配置多重資產基金-累積類型南非幣計價 complete
# 17 野村動態配置多重資產基金-月配類型澳幣計價
# 17 野村動態配置多重資產基金-月配類型澳幣計價 complete
# 18 野村動態配置多重資產基金-累積類型澳幣計價
# 18 野村動態配置多重資產基金-累積類型澳幣計價 complete
# 19 野村動態配置多重資產基金-月配類型南非幣計價
# 19 野村動態配置多重資產基金-月配類型南非幣計價 complete
# 20 野村六年階梯到期亞太新興債券基金（南非幣年配
# 20 野村六年階梯到期亞太新興債券基金（南非幣年配 complete
# 21 野村六年階梯到期亞太新興債券基金（南非幣累積
# 21 野村六年階梯到期亞太新興債券基金（南非幣累積 complete
# 22 野村六年目標到期亞太新興債券基金（南非幣累積
# 22 野村六年目標到期亞太新興債券基金（南非幣累積 complete
# 23 野村六年目標到期亞太新興債券基金（南非幣年配
# 23 野村六年目標到期亞太新興債券基金（南非幣年配 complete
# 24 野村環球基金-S類型新臺幣累積
# 24 野村環球基金-S類型新臺幣累積 complete
# 25 野村邊境市場高收益主權債基金（新台幣月配）
# 25 野村邊境市場高收益主權債基金（新台幣月配） complete
# 26 野村邊境市場高收益主權債基金（新台幣累積）
# 26 野村邊境市場高收益主權債基金（新台幣累積） complete
# 27 野村邊境市場高收益主權債基金（美元月配）
# 27 野村邊境市場高收益主權債基金（美元月配） complete
# 28 野村邊境市場高收益主權債基金（人民幣月配）
# 28 野村邊境市場高收益主權債基金（人民幣月配） complete
# 29 野村邊境市場高收益主權債基金（人民幣累積）
# 29 野村邊境市場高收益主權債基金（人民幣累積） complete
# 30 野村邊境市場高收益主權債基金（美元累積）
# 30 野村邊境市場高收益主權債基金（美元累積） complete
# 31 野村環球基金-累積類型新臺幣計價
# 31 野村環球基金-累積類型新臺幣計價 complete
# 32 野村環球基金-美元計價
# 32 野村環球基金-美元計價 complete
# 33 野村動態配置多重資產基金-S類型新臺幣累積
# 33 野村動態配置多重資產基金-S類型新臺幣累積 complete
# 34 野村動態配置多重資產基金-月配類型新臺幣計價
# 34 野村動態配置多重資產基金-月配類型新臺幣計價 complete
# 35 野村動態配置多重資產基金-累積類型新臺幣計價
# 35 野村動態配置多重資產基金-累積類型新臺幣計價 complete
# 36 野村全球品牌基金
# 36 野村全球品牌基金 complete
# 37 野村泰國基金
# 37 野村泰國基金 complete
# 38 野村動態配置多重資產基金-月配類型美元計價
# 38 野村動態配置多重資產基金-月配類型美元計價 complete
# 39 野村動態配置多重資產基金-累積類型美元計價
# 39 野村動態配置多重資產基金-累積類型美元計價 complete
# 40 野村動態配置多重資產基金-累積類型人民幣計價
# 40 野村動態配置多重資產基金-累積類型人民幣計價 complete
# 41 野村動態配置多重資產基金-月配類型人民幣計價
# 41 野村動態配置多重資產基金-月配類型人民幣計價 complete
# 42 野村全球不動產證券化基金-月配類型人民幣計價
# 42 野村全球不動產證券化基金-月配類型人民幣計價 complete
# 43 野村多元收益平衡基金-月配類型新臺幣計價
# 43 野村多元收益平衡基金-月配類型新臺幣計價 complete
# 44 野村五年階梯到期新興市場債券基金（美元累積）
# 44 野村五年階梯到期新興市場債券基金（美元累積） complete
# 45 野村多元收益平衡基金-累積類型新臺幣計價
# 45 野村多元收益平衡基金-累積類型新臺幣計價 complete
# 46 野村全球不動產證券化基金-累積類型人民幣計價
# 46 野村全球不動產證券化基金-累積類型人民幣計價 complete
# 47 野村多元收益平衡基金-累積類型美元計價
# 47 野村多元收益平衡基金-累積類型美元計價 complete
# 48 野村多元收益平衡基金-月配類型美元計價
# 48 野村多元收益平衡基金-月配類型美元計價 complete
# 49 野村新興高收益債組合基金-累積型
# 49 野村新興高收益債組合基金-累積型 complete
# 50 野村多元收益平衡基金-累積類型人民幣計價
# 50 野村多元收益平衡基金-累積類型人民幣計價 complete
# 51 野村多元收益平衡基金-月配類型人民幣計價
# 51 野村多元收益平衡基金-月配類型人民幣計價 complete
# 52 野村新興高收益債組合基金-S類型新臺幣累積
# 52 野村新興高收益債組合基金-S類型新臺幣累積 complete
# 53 野村新興高收益債組合基金-月配型
# 53 野村新興高收益債組合基金-月配型 complete
# 54 野村全球不動產證券化基金累積型新臺幣計價
# 54 野村全球不動產證券化基金累積型新臺幣計價 complete
# 55 野村六年目標到期亞太新興債券基金（人民幣年配
# 55 野村六年目標到期亞太新興債券基金（人民幣年配 complete
# 56 野村六年目標到期亞太新興債券基金（人民幣累積
# 56 野村六年目標到期亞太新興債券基金（人民幣累積 complete
# 57 野村鑫平衡組合基金-累積類型
# 57 野村鑫平衡組合基金-累積類型 complete
# 58 野村六年階梯到期亞太新興債券基金（人民幣年配
# 58 野村六年階梯到期亞太新興債券基金（人民幣年配 complete
# 59 野村歐洲高股息基金季配型
# 59 野村歐洲高股息基金季配型 complete
# 60 野村六年目標到期亞太新興債券基金（澳幣累積）
# 60 野村六年目標到期亞太新興債券基金（澳幣累積） complete
# 61 野村六年階梯到期亞太新興債券基金（人民幣累積
# 61 野村六年階梯到期亞太新興債券基金（人民幣累積 complete
# 62 野村六年目標到期亞太新興債券基金（美元年配）
# 62 野村六年目標到期亞太新興債券基金（美元年配） complete
# 63 野村六年目標到期亞太新興債券基金（美元累積）
# 63 野村六年目標到期亞太新興債券基金（美元累積） complete
# 64 野村六年目標到期亞太新興債券基金（澳幣年配）
# 64 野村六年目標到期亞太新興債券基金（澳幣年配） complete
# 65 野村六年階梯到期新興市場債券基金-人民幣
# 65 野村六年階梯到期新興市場債券基金-人民幣 complete
# 66 野村鑫全球債券組合基金-累積類型
# 66 野村鑫全球債券組合基金-累積類型 complete
# 67 野村六年階梯到期亞太新興債券基金（澳幣年配）
# 67 野村六年階梯到期亞太新興債券基金（澳幣年配） complete
# 68 野村美利堅高收益債基金-月配類型新臺幣計價
# 68 野村美利堅高收益債基金-月配類型新臺幣計價 complete
# 69 野村鑫全球債券組合基金-S類型新臺幣累積
# 69 野村鑫全球債券組合基金-S類型新臺幣累積 complete
# 70 野村五年階梯到期新興市場債券基金（人民幣累積
# 70 野村五年階梯到期新興市場債券基金（人民幣累積 complete
# 71 野村六年目標到期新興市場債券基金美元
# 71 野村六年目標到期新興市場債券基金美元 complete
# 72 野村六年階梯到期亞太新興債券基金（澳幣累積）
# 72 野村六年階梯到期亞太新興債券基金（澳幣累積） complete
# 73 野村五年階梯到期新興市場債券基金（人民幣季配
# 73 野村五年階梯到期新興市場債券基金（人民幣季配 complete
# 74 野村六年階梯到期亞太新興債券基金（美元年配）
# 74 野村六年階梯到期亞太新興債券基金（美元年配） complete
# 75 野村六年階梯到期亞太新興債券基金（美元累積）
# 75 野村六年階梯到期亞太新興債券基金（美元累積） complete
# 76 野村六年目標到期新興市場債券基金人民幣
# 76 野村六年目標到期新興市場債券基金人民幣 complete
# 77 野村六年階梯到期新興市場債券基金-美元
# 77 野村六年階梯到期新興市場債券基金-美元 complete
# 78 野村美利堅高收益債基金-S類型新臺幣累積
# 78 野村美利堅高收益債基金-S類型新臺幣累積 complete
# 79 野村美利堅高收益債基金-累積類型新臺幣計價
# 79 野村美利堅高收益債基金-累積類型新臺幣計價 complete
# 80 野村五年階梯到期新興市場債券基金（美元季配）
# 80 野村五年階梯到期新興市場債券基金（美元季配） complete
# 81 野村五年階梯到期新興市場債券基金（新台幣累積
# 81 野村五年階梯到期新興市場債券基金（新台幣累積 complete
# 82 野村全球高股息基金累積型新臺幣計價
# 82 野村全球高股息基金累積型新臺幣計價 complete
# 83 野村-2024-目標到期新興市場企業債券基金
# 83 野村-2024-目標到期新興市場企業債券基金 complete
# 84 野村-2024-目標到期新興市場企業債券基金
# 84 野村-2024-目標到期新興市場企業債券基金 complete
# 85 野村-2024-目標到期新興市場企業債券基金
# 85 野村-2024-目標到期新興市場企業債券基金 complete
# 86 野村四年階梯到期新興市場債券基金累積類型人民
# 86 野村四年階梯到期新興市場債券基金累積類型人民 complete
# 87 野村四年階梯到期新興市場債券基金累積類型美元
# 87 野村四年階梯到期新興市場債券基金累積類型美元 complete
# 88 野村環球高收益債基金-月配類型新臺幣計價
# 88 野村環球高收益債基金-月配類型新臺幣計價 complete
# 89 野村四年階梯到期新興市場債券基金季配類型人民
# 89 野村四年階梯到期新興市場債券基金季配類型人民 complete
# 90 野村全球高股息基金-S類型新臺幣累積
# 90 野村全球高股息基金-S類型新臺幣累積 complete
# 91 野村全球高股息基金-季配類型人民幣計價
# 91 野村全球高股息基金-季配類型人民幣計價 complete
# 92 野村亞太複合高收益債基金-累積類型美元計價
# 92 野村亞太複合高收益債基金-累積類型美元計價 complete
# 93 野村-2024-目標到期新興市場企業債券基金
# 93 野村-2024-目標到期新興市場企業債券基金 complete
# 94 野村環球高收益債基金-S類型新臺幣累積
# 94 野村環球高收益債基金-S類型新臺幣累積 complete
# 95 野村鑫平衡組合基金-S類型新臺幣累積
# 95 野村鑫平衡組合基金-S類型新臺幣累積 complete
# 96 野村全球不動產證券化基金月配型新臺幣計價
# 96 野村全球不動產證券化基金月配型新臺幣計價 complete
# 97 野村亞太複合高收益債基金-月配類型美元計價
# 97 野村亞太複合高收益債基金-月配類型美元計價 complete
# 98 野村環球高收益債基金-累積類型新臺幣計價
# 98 野村環球高收益債基金-累積類型新臺幣計價 complete
# 99 野村環球高收益債基金-累積類型美元計價
# 99 野村環球高收益債基金-累積類型美元計價 complete
# 100 野村亞太複合高收益債基金-月配類型人民幣計價
# 100 野村亞太複合高收益債基金-月配類型人民幣計價 complete
# 101 野村四年階梯到期新興市場債券基金季配類型美元
# 101 野村四年階梯到期新興市場債券基金季配類型美元 complete
# 102 野村環球高收益債基金-月配類型美元計價
